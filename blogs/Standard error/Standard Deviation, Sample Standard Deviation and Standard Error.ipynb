# %% [raw]
# ---
# title: "Standard Deviation and Standard Error"
# editor: visual
# ---

# %% [markdown]
# ```{css, echo = FALSE}
# .justify {
#   text-align: justify !important
# }
# ```
#
#
#
#
# # Introduction
# ::: {.justify}
# In a introductory statistics class, terms like population, parameter, sample are explained. Population describes a collection of all units. A population is defined by a common feature. Suppose we are interested in the ages of college freshmen on a university campus, if we are able to measure and record all the ages of the freshmen then that become our population with the common feature being "college freshmen on the campus". Another important term is parameter, a numerical characteristic of a population. Realistically, it is expensive and time wasting to attempt to collect all information on a population. This leads us to the term "sample". A sample describes a subset of a population. Using the college freshmen example, does taking the ages of only History majors constitute a sample? Here, we use sample to mean random sample. Random in the sense that every student has equal chance of being included in the sample. Focusing only on History majors is not a random sample. Random sample will be **randomly** selecting 1000 college freshmen on the college campus.
#
# Standard deviation and mean are some of the common population parameters. In the realms of statistics, parameters are unknown(Do you see why?). Not knowing the parameters for any given population is not the end of the road. With a sample, we can estimate what the population mean and standard deviation are. Thus, sample mean and sample standard deviation estimate the unknown mean and standard deviation of a population.
#
# :::
#
# # Conclusion
