# %% [raw]
# ---
# title: "Theophilus Anim Bediako"
# toc: false
# about:
#   template: jolla
#   image: media/theo.jpg
#   image-shape: round
#   image-width: 17em
#   links:
#     - icon: linkedin
#       href: https://www.linkedin.com/in/theophilus-anim-bediako
#     - icon: github
#       href: https://github.com/TheoAnim
#     - icon: envelope
#       href: mailto:theophilus.animbediako@gmail.com
# ---

# %% [markdown]
# ```{css, echo = FALSE}
# .justify {
#   text-align: justify !important
# }
# ```
#
#
#
#
# ::: {.justify}
# You are welcome!
#
# I am a second-year PhD student in the [Department of Statistical Science](https://statistics.artsandsciences.baylor.edu/) at [Baylor University, Waco, Texas](https://www.baylor.edu/). I graduated with a master's degree in Mathematics-Statistics from [South Dakota State University](https://www.sdstate.edu/programs/graduate/mathematics-ms-statistics-specialization) where I had the opportunity to build a strong foundation in Linear Algebra, Machine Learning(Clustering & Classification Algorithms) and Probability Theory. With this experience, I believe I am well-prepared to take on new and challenging projects in Statistics and Machine Learning.
#
#
# At [Baylor](https://www.baylor.edu/), I continue to learn statistical methods for Bayesian Inference, Survival Analysis.
#
#
# Outside the classroom, I do spend time talking to my family and taking nature photographs along the Brazos river.
#
# Learn about my professional and academic journey here on this page!
#
# :::
